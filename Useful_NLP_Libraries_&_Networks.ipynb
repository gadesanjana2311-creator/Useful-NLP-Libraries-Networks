# %% [markdown]
# **Question 1: Compare and contrast NLTK and spaCy in terms of features, ease of use, and performance.**
#
# **Answer**:-
#
# | Aspect      | NLTK                   | spaCy                     |
# | ----------- | ---------------------- | ------------------------- |
# | Purpose     | Education & research   | Production & applications |
# | Ease of use | Moderate to difficult  | Easy and intuitive        |
# | Performance | Slower                 | Very fast                 |
# | Features    | Very wide and academic | Focused and practical     |
# | Best for    | Learning NLP concepts  | Building NLP systems      |

# %% [markdown]
# **Question 2: What is TextBlob and how does it simplify common NLP tasks like sentiment analysis and translation?**
# **Answer:-**
#
# TextBlob provides a simple, intuitive API for performing basic NLP operations without needing deep knowledge of algorithms or model building. It abstracts complex NLP workflows into easy function calls.
#
# Sentiment analysis is the process of determining whether a text is positive, negative, or neutral.
#
# TextBlob also provides a built-in interface for language translation, using external translation APIs.
#
#  **NLP Tasks Simplified by TextBlob**
#
# Tokenization (splitting text into words/sentences)
#
# Part-of-speech tagging
#
# Noun phrase extraction
#
# Spelling correction

# %% [markdown]
# **Question 3: Explain the role of Standford NLP in academic and industry NLP Projects.**
#
# **Answer:-**
#
# The Stanford CoreNLP suite (often referred to as Stanford NLP) is a widely used collection of NLP tools developed by Stanford University. It plays a significant role in both academic research and industry applications due to its accuracy, robustness, and comprehensive linguistic analysis capabilities.
#
# 1. Role in Academic NLP Projects
#
# In academic research, Stanford NLP is mainly used for:
#
# a) Linguistic Research and Analysis
#
# Provides tools for deep linguistic processing such as:
#
# Tokenization
#
# Part-of-speech (POS) tagging
#
# Named Entity Recognition (NER)
#
# Dependency parsing
#
# Helps researchers study grammar, syntax, and semantics of
#
# natural language.
#
# b) Benchmarking and Experimentation
#
# Often used as a baseline system in NLP research papers.
#
# Enables comparison of new models against well-established
#
# linguistic pipelines.
#
# c) Educational Use
#
# Widely used in universities to teach:
#
# Syntax parsing
#
# Information extraction
#
# NLP pipeline design
#
# 2. Role in Industry NLP Projects
#
# In industry, Stanford NLP is used for robust text processing and information extraction, especially in data-heavy environments.
#
# a) Information Extraction
#
# Extracts structured information from unstructured text:
# N
# ames of people, organizations, locations (NER)
#
# Relationships between entities
#
# b) Text Analytics
#
# Used in:
#
# Customer feedback analysis
#
# Social media monitoring
#
# Document classification pipelines
#
# c) Question Answering and Chatbots
#
# Dependency parsing and semantic analysis help improve:
#
# Intent detection
#
# Query understanding in NLP systems

# %% [markdown]
# **Question 4: Describe the architecture and functioning of a Recurrent Natural Network(RNN).**
#
# **Answer:-**
#
# A Recurrent Neural Network (RNN) is a type of neural network designed to work with sequential data such as text, speech, or time series. Unlike traditional neural networks, RNNs have a “memory” that helps them retain information from previous inputs.
#
# 1. Architecture of an RNN
#
# The key idea in an RNN is the recurrent connection, where the output from the previous step is fed back into the network.
#
# 2. Working (How RNN Functions)
#
# Step-by-step process:
#
# Input Sequence Processing
#
# The RNN processes input one element at a time (e.g., word by word in a sentence).
#
# Hidden State Update
# It combines the current input with the previous memory (hidden state).
#
# Memory Retention
#
# The hidden state acts as a memory that stores past information.
#
# Output Generation
# At each step or at the end, the network produces an output.
#
# 3. Example (Text Processing)
#
# Sentence: “I love NLP”
#
# | Step | Input | Hidden State Memory |
# | ---- | ----- | ------------------- |
# | t1   | I     | Stores “I”          |
# | t2   | love  | Stores “I love”     |
# | t3   | NLP   | Stores “I love NLP” |
#
# 4. Strengths of RNN
#
# Good for sequential data (text, speech)
#
# Shares parameters across time steps
#
# Captures short-term dependencies
#
# 5. Limitations of RNN
#
# Struggles with long-term dependencies (vanishing gradient problem)
#
# Computationally slow for long sequences
#
# Replaced in many cases by LSTM and GRU variants
#
#
#
# 	​

# %% [markdown]
# **Question 5: What is the key difference between LSTM and GRU networks in NLP applications?**
#
# **Answer:-**
#
# | Feature          | LSTM (Long Short-Term Memory)      | GRU (Gated Recurrent Unit)   |
# | ---------------- | ---------------------------------- | ---------------------------- |
# | Gates            | 3 gates (input, forget, output)    | 2 gates (reset, update)      |
# | Memory structure | Separate cell state + hidden state | Single hidden state          |
# | Complexity       | More complex                       | Simpler                      |
# | Parameters       | More parameters                    | Fewer parameters             |
# | Training speed   | Slower                             | Faster                       |
# | Performance      | Strong for long-term dependencies  | Comparable in many NLP tasks |
# | Overfitting risk | Higher (due to complexity)         | Lower                        |

# %%
#Question 6: Write a Python program using TextBlob to perform sentiment analysis on the following paragraph o
from textblob import TextBlob

# Input text
text = """I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating"""

# Create TextBlob object
blob = TextBlob(text)

# Get sentiment
polarity = blob.sentiment.polarity
subjectivity = blob.sentiment.subjectivity

# Print results
print("Polarity:", polarity)
print("Subjectivity:", subjectivity)
# Out:
# Polarity: 0.21742424242424244
# Subjectivity: 0.6511363636363636

# %%
#Question 7: Given the sample paragraph below, perform string tokenization and frequency distribution using Python and NLTK: “Natural Language Processing (NLP) is a fascinating field that combines linguistics, computer science, and artificial intelligence. It enables machines to understand, interpret, and generate human language. Applications of NLP include chatbots, sentiment analysis, and machine translation. As technology advances, the role of NLP in modern solutions is becoming increasingly critical.”
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Download required resources (run once)
nltk.download('punkt')
nltk.download('punkt_tab')

# Input text
text = """Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical."""

# Step 1: Tokenization (word-level)
tokens = word_tokenize(text)

# Step 2: Convert to lowercase for better frequency analysis
tokens = [word.lower() for word in tokens if word.isalnum()]

# Step 3: Frequency Distribution
fdist = FreqDist(tokens)

# Print tokens
print("Tokens:\n", tokens)

# Print frequency distribution
print("\nWord Frequencies:")
for word, freq in fdist.items():
    print(word, ":", freq)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens:
#  ['natural', 'language', 'processing', 'nlp', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', 'computer', 'science', 'and', 'artificial', 'intelligence', 'it', 'enables', 'machines', 'to', 'understand', 'interpret', 'and', 'generate', 'human', 'language', 'applications', 'of', 'nlp', 'include', 'chatbots', 'sentiment', 'analysis', 'and', 'machine', 'translation', 'as', 'technology', 'advances', 'the', 'role', 'of', 'nlp', 'in', 'modern', 'solutions', 'is', 'becoming', 'increasingly', 'critical']
#
# Word Frequencies:
# natural : 1
# language : 2
# processing : 1
# nlp : 3
# is : 2
# a : 1
# fascinating : 1
# field : 1
# that : 1
# combines : 1
# linguistics : 1
# computer : 1
# science : 1
# and : 3
# artificial : 1
# ...

# %%
#Question 8: Implement a basic LSTM model in Keras for a text classification task using the following dummy dataset. Your model should classify sentences as either positive (1) or negative (0).
# Dataset
#texts = [
#“I love this project”, #Positive
#“This is an amazing experience”, #Positive
#“I hate waiting in line”, #Negative
#“This is the worst service”, #Negative
#“Absolutely fantastic!” #Positive
#]
#labels = [1, 1, 0, 0, 1]
#Preprocess the text, tokenize it, pad sequences, and build an LSTM model to train on this data. You may use Keras with TensorFlow backend.
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Dataset
texts = [
    "I love this project",
    "This is an amazing experience",
    "I hate waiting in line",
    "This is the worst service",
    "Absolutely fantastic!"
]

labels = [1, 1, 0, 0, 1]

# Step 1: Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

# Step 2: Padding sequences
max_len = max(len(seq) for seq in sequences)
X = pad_sequences(sequences, maxlen=max_len, padding='post')

y = np.array(labels)

# Step 3: Vocabulary size
vocab_size = len(tokenizer.word_index) + 1

# Step 4: Build LSTM model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=16, input_length=max_len))
model.add(LSTM(32))
model.add(Dense(1, activation='sigmoid'))

# Step 5: Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Step 6: Train model
model.fit(X, y, epochs=10, verbose=1)

# Step 7: Evaluate predictions
predictions = model.predict(X)

print("\nPredictions:")
print(predictions)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.4000 - loss: 0.6924
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6000 - loss: 0.6905
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6000 - loss: 0.6887
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6000 - loss: 0.6868
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.6849
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.6829
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.6808
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.6786
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.6762
# Epoch 10/10
# ...

# %%
#Question 9: Using spaCy, build a simple NLP pipeline that includes tokenization, lemmatization, and entity recognition. Use the following paragraph as your dataset: “Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the development of India’s atomic energy program. He was the founding director of the Tata Institute of Fundamental Research (TIFR) and was instrumental in establishing the Atomic Energy Commission of India.” Write a Python program that processes this text using spaCy, then prints tokens, their lemmas, and any named entities found.
import spacy

# Load English model
nlp = spacy.load("en_core_web_sm")

# Input text
text = """Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
development of India’s atomic energy program. He was the founding director of the Tata
Institute of Fundamental Research (TIFR) and was instrumental in establishing the
Atomic Energy Commission of India."""

# Process text using spaCy pipeline
doc = nlp(text)

# ---------------------------
# Tokenization + Lemmatization
# ---------------------------
print("TOKENS AND LEMMAS:\n")
for token in doc:
    if not token.is_punct and not token.is_space:
        print(f"Token: {token.text:<10} Lemma: {token.lemma_}")

# ---------------------------
# Named Entity Recognition
# ---------------------------
print("\nNAMED ENTITIES:\n")
for ent in doc.ents:
    print(f"Entity: {ent.text:<50} Label: {ent.label_}")
# Out:
# TOKENS AND LEMMAS:
#
# Token: Homi       Lemma: Homi
# Token: Jehangir   Lemma: Jehangir
# Token: Bhaba      Lemma: Bhaba
# Token: was        Lemma: be
# Token: an         Lemma: an
# Token: Indian     Lemma: indian
# Token: nuclear    Lemma: nuclear
# Token: physicist  Lemma: physicist
# Token: who        Lemma: who
# Token: played     Lemma: play
# Token: a          Lemma: a
# Token: key        Lemma: key
# Token: role       Lemma: role
# Token: in         Lemma: in
# Token: the        Lemma: the
# Token: development Lemma: development
# Token: of         Lemma: of
# Token: India      Lemma: India
# Token: ’s         Lemma: ’s
# Token: atomic     Lemma: atomic
# Token: energy     Lemma: energy
# Token: program    Lemma: program
# Token: He         Lemma: he
# Token: was        Lemma: be
# Token: the        Lemma: the
# Token: founding   Lemma: found
# Token: director   Lemma: director
# Token: of         Lemma: of
# Token: the        Lemma: the
# Token: Tata       Lemma: Tata
# ...

# %% [markdown]
# **Question 10: You are working on a chatbot for a mental health platform. Explain how you would leverage LSTM or GRU networks along with libraries like spaCy or Stanford NLP to understand and respond to user input effectively. Detail your architecture, data preprocessing pipeline, and any ethical considerations.**
#
# **Answer:-**
#
# **1. Overall Architecture**
#
# A practical architecture would look like this:
#
# User Input → NLP Preprocessing → Feature Representation → LSTM/GRU Model → Intent/Emotion Detection → Response Generator → Safety Filter → Output
#
# More clearly:
#
# Input Layer
#
# User types a message (e.g., “I feel very anxious and lonely”)
#
# Preprocessing Layer (spaCy / Stanford NLP)
#
# Tokenization
#
# Lemmatization
#
# Stopword removal (optional)
#
# Named Entity Recognition (optional for context like dates, events)
#
# Dependency parsing (optional for intent understanding)
#
# Text Representation
#
# Word embeddings (Word2Vec / GloVe / FastText) or
#
# Keras Embedding layer
#
# Sequence Model
#
# LSTM or GRU
#
# Captures context, emotional tone, and sequence meaning
#
# Output Layer
#
# Softmax for intent classification (e.g., anxiety, depression, greeting)
#
# OR sigmoid for emotion detection (multi-label)
#
# Response Generator
#
# Template-based responses OR
#
# Retrieval-based chatbot OR
#
# Sequence-to-sequence model (advanced)
#
# Safety & Ethics Layer
#
# Filters harmful outputs
#
# Crisis detection (self-harm signals)
#
# Escalation to human counselor
#
#  **2. Data Preprocessing Pipeline**
#
# Using spaCy / Stanford NLP, the pipeline includes:
#
# Step 1: Cleaning
#
# Lowercasing text
#
# Removing punctuation, URLs, emojis (if needed)
#
# Step 2: Tokenization (spaCy / Stanford NLP)
#
# Splits sentence into tokens
#
# Step 3: Lemmatization
#
# Converts words to base form:
#
# “feeling” → “feel”
#
# Step 4: Stopword Handling
#
# Remove words like “is”, “the”, “and” (optional depending on model)
#
# Step 5: Named Entity Recognition (NER)
#
# Detect important entities like:
#
# time (“today”, “yesterday”)
#
# locations (for context-aware support)
#
# Step 6: Vectorization
#
# Convert tokens into embeddings:
#
# Word2Vec / GloVe / FastText
#
# Or trainable embedding layer in Keras
#
#
# **3. Role of spaCy / Stanford NLP**
#
# | Task               | spaCy / Stanford NLP Role     |
# | ------------------ | ----------------------------- |
# | Tokenization       | Break text into words         |
# | Lemmatization      | Normalize words               |
# | POS tagging        | Understand grammar            |
# | NER                | Extract entities              |
# | Dependency parsing | Understand sentence structure |
# | Task               | spaCy / Stanford NLP Role     |
# | ------------------ | ----------------------------- |
# | Tokenization       | Break text into words         |
# | Lemmatization      | Normalize words               |
# | POS tagging        | Understand grammar            |
# | NER                | Extract entities              |
# | Dependency parsing | Understand sentence structure |
